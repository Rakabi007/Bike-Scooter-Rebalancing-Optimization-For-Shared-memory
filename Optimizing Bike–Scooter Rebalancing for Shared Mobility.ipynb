# %% [markdown]
# <a href="https://colab.research.google.com/github/Rakabi007/Bike-Scooter-Rebalancing-Optimization-For-Shared-memory/blob/main/Optimizing%20Bike%E2%80%93Scooter%20Rebalancing%20for%20Shared%20Mobility.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math, random, requests
import numpy as np, pandas as pd, geopandas as gpd
from shapely.geometry import Point
import networkx as nx
import folium
from folium import FeatureGroup, LayerControl
